# %%
import re
import json
import pandas as pd

# %%
client_id = '6eUWzJrvj458IHKSWShA'
client_secret = 'ZvrD2F54fy'
keyword = '복합인공지능'

# %%
search_word= re.sub('[^0-9a-zA-Zㄱ-힗]', '', keyword)

# %%
import os
import sys
import urllib.request
client_id = "6eUWzJrvj458IHKSWShA"
client_secret = "ZvrD2F54fy"
query = urllib.parse.quote("복합 인공지능")
idx = 0
start = 1
end = 1000
display = 100
web_df= pd.DataFrame(columns=('Title', 'Link', 'Description'))
url = "https://openapi.naver.com/v1/search/webkr?query=" + query + '&display=' + str(display) + '&start=' + str(start)

request = urllib.request.Request(url)
request.add_header("X-Naver-Client-Id",client_id)
request.add_header("X-Naver-Client-Secret",client_secret)
response = urllib.request.urlopen(request)
rescode = response.getcode()
if(rescode==200):
    response_body = response.read()
    response_dict = json.loads(response_body.decode('utf-8'))
    items = response_dict['items']
    for items_index in range(0, len(items)):
        remove_tag = re.compile('<.*?>')
        title = re.sub(remove_tag, '', items[items_index]['title'])
        link = items[items_index]['link']
        description = re.sub(remove_tag, '', items[items_index]['title'])
        link = items[items_index]['link']
        description = re.sub(remove_tag, '', items[items_index]['description'])
        web_df.loc[idx] = [title, link, description]
        idx += 1
    print(response_body.decode('utf-8'))
else:
    print("Error Code:" + rescode)
# Out:
# {
# 	"lastBuildDate":"Sun, 17 Dec 2023 15:32:05 +0900",
# 	"total":8863120,
# 	"start":1,
# 	"display":75,
# 	"items":[
# 		{
# 			"title":"학과소개 | 대학소개 | <b>인공지능<\/b>학과",
# 			"link":"https:\/\/www.uos.ac.kr\/engineering\/depart\/ai\/introduct.do",
# 			"description":"인간중심의 <b>인공지능<\/b>을 지향합니다. <b>인공지능<\/b> 기술이 가져올 미래 사회와 첨단 기술 및 산업에서의 <b>인공지능<\/b>의 중추적 역할에 비추어 볼 때, 다양하고 <b>복합<\/b>적인 <b>인공지능<\/b> 핵심 기술을 체계적이며 종합적으로 이해하고 활용할 수 있는 탁월한 전문성을 갖춘 윤리적인 인재의 양성을 주도적으로 담당할 <b>인공지능<\/b>학과의 필요성에 따라 2020년도 4월에 신설되어 <b>인공지능<\/b> 분야의 수준 높은 교육과 연구를 목표로 우수한 ..."
# 		},
# 		{
# 			"title":"4차 산업혁명 시대, <b>인공지능<\/b>의 역할은? – Samsung Newsroom Korea",
# 			"link":"https:\/\/news.samsung.com\/kr\/4%EC%B0%A8-%EC%82%B0%EC%97%85%ED%98%81%EB%AA%85-%EC%8B%9C%EB%8C%80-%EC%9D%B8%EA%B3%B5%EC%A7%80%EB%8A%A5%EC%9D%98-%EC%97%AD%ED%95%A0%EC%9D%80",
# ...

# %%
web_df
# Out:
#                                                 Title  \
# 0                                학과소개 | 대학소개 | 인공지능학과
# 1     4차 산업혁명 시대, 인공지능의 역할은? – Samsung Newsroom Korea
# 2   [특허칼럼] 인공지능 분야의 특허 사례 &lt; 칼럼 &lt; 오피니언 &lt; 기...
# 3                         눈앞에 다가온 인공지능 시대… '복합지능' 길러라
# 4           [재미있는 ICT] 우리는 지금 `인공지능의 시대`에 살고있다 - 매일경제
# ..                                                ...
# 70              이노크아든 인공지능스마트IOT 복합식 가습기IA-H200A - 옥션
# 71              이노크아든 인공지능스마트IOT 복합식 가습기IA-H200A - 옥션
# 72                             광양에 인공지능블록체인 복합교육관 들어서
# 73       LG 복합오븐 MLJ39CW [ 에어프라이어 / 인공지능쿡 / 스마트 인버터 ]
# 74                                             AI-Hub
#
#                                                  Link  \
# 0   https://www.uos.ac.kr/engineering/depart/ai/in...
# 1   https://news.samsung.com/kr/4%EC%B0%A8-%EC%82%...
# 2   https://www.newscj.com/news/articleView.html?i...
# 3   https://edu.chosun.com/site/data/html_dir/2017...
# ...

# %%
data = response_body.decode('utf-8').replace('[^가-힣]', '', regex=True)
# Out:
# Unexpected exception formatting exception. Falling back to standard exception
# Traceback (most recent call last):
#   File "C:\Users\holly\AppData\Roaming\Python\Python39\site-packages\IPython\core\interactiveshell.py", line 3550, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "C:\Users\holly\AppData\Local\Temp\ipykernel_20348\2462019053.py", line 1, in <module>
#     data = response_body.decode('utf-8').replace('[^가-힣]', '', regex=True)
# TypeError: str.replace() takes no keyword arguments
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\holly\AppData\Roaming\Python\Python39\site-packages\IPython\core\interactiveshell.py", line 2144, in showtraceback
#     stb = self.InteractiveTB.structured_traceback(
#   File "C:\Users\holly\AppData\Roaming\Python\Python39\site-packages\IPython\core\ultratb.py", line 1435, in structured_traceback
# ...

# %%
with open('rescode', 'r') as f:
    data = json.load(f)
print(data)
# Out:
# 200
